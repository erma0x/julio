# %%
! pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

def get_links(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        links = [a['href'] for a in soup.find_all('a', href=True)]
        return links
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []

if __name__ == "__main__":
    url = "https://www.miodottore.it/cerca?q=nutrizionista&loc=Roma&filters%5Bspecializations%5D%5B0%5D=108&page=2"
    links = get_links(url)
    for link in links:
        if '.it/' in link:
            print(link)
# Out:
# https://www.miodottore.it/registrazione-medico
# https://pro.miodottore.it/?utm_source=MKTP&utm_medium=referral&utm_campaign=top-nav
# https://www.miodottore.it/valentina-rimatori/nutrizionista/roma
# https://www.miodottore.it/valentina-rimatori/nutrizionista/roma
# https://www.miodottore.it/valentina-rimatori/nutrizionista/roma#profile-reviews
# https://www.miodottore.it/gabriele-papagni/nutrizionista/roma
# https://www.miodottore.it/gabriele-papagni/nutrizionista/roma
# https://www.miodottore.it/gabriele-papagni/nutrizionista/roma#profile-reviews
# https://www.miodottore.it/settimio-albis/nutrizionista-dietista-dietologo/margherita-di-savoia
# https://www.miodottore.it/settimio-albis/nutrizionista-dietista-dietologo/margherita-di-savoia
# https://www.miodottore.it/settimio-albis/nutrizionista-dietista-dietologo/margherita-di-savoia#profile-reviews
# https://www.miodottore.it/alessandro-solidoro/nutrizionista/roma
# https://www.miodottore.it/alessandro-solidoro/nutrizionista/roma
# ...

# %%
import re
import requests

def find_phone_number(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        phone_pattern = r"\b\d{2,4}\s?\d{6,10}\b"  # Regular expression pattern to match phone numbers
        matches = re.findall(phone_pattern, response.text)
        return matches
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []

if __name__ == "__main__":
    url = "https://www.miodottore.it/valentina-rimatori/nutrizionista/roma"
    phone_numbers = find_phone_number(url)
    if phone_numbers:
        print("Phone numbers found:")
        for number in phone_numbers:
            print(number)
    else:
        print("No phone numbers found on the page.")

    #elemento_maggiormente_ripetuto = elemento_piu_ripetuto(phone_numbers)
# Out:
# Phone numbers found:
# 202211201558
# 202211201558
# 116553255
# 447506495597
# 1799301098
# 1799301098
# 1690591733
# 09244850963
# 2370760445
# 308928267
# 1663281546
# 2538961389
# 0697622323
# 0697622323
# 0697622323
# 0697622323
# 0697622323
# 0697622323
# 09244850963

# %%
def lista_senza_ripetizioni(lista):
    lista_senza_duplicati = list(set(lista))
    return lista_senza_duplicati

# Esempio di utilizzo della funzione
if __name__ == "__main__":
    lista_di_elementi = [1, 2, 3, 4, 2, 2, 5, 6, 4, 4, 2, 7, 2]
    lista_senza_duplicati = lista_senza_ripetizioni(lista_di_elementi)
    print("Lista senza ripetizioni:", lista_senza_duplicati)
# Out:
# Lista senza ripetizioni: [1, 2, 3, 4, 5, 6, 7]

# %%
lista_senza_duplicati = lista_senza_ripetizioni(phone_numbers)
lista_senza_duplicati
# Out:
# ['447506495597',
#  '202211201558',
#  '308928267',
#  '0697622323',
#  '09244850963',
#  '2370760445',
#  '2538961389',
#  '116553255',
#  '1690591733',
#  '1799301098',
#  '1663281546']

# %%
from collections import Counter

def elemento_piu_ripetuto(lista):
    # Utilizziamo Counter per contare le occorrenze degli elementi nella lista
    conteggio = Counter(lista)

    # Troviamo l'elemento con la conteggio massimo
    elemento_piu_comune = conteggio.most_common(1)[0][0]

    return elemento_piu_comune

# Esempio di utilizzo della funzione
if __name__ == "__main__":
    lista_di_elementi = [1, 2, 3, 4, 2, 2, 5, 6, 4, 4, 2, 7, 2]

    elemento_maggiormente_ripetuto = elemento_piu_ripetuto(phone_numbers)
    print("L'elemento maggiormente ripetuto è:", elemento_maggiormente_ripetuto)
# Out:
# L'elemento maggiormente ripetuto è: 0697622323

# %%
import requests
from bs4 import BeautifulSoup

def get_username(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        
        username_element = soup.find('span', itemprop='name')

        if username_element:
            username = username_element.text.strip()
            return username
        else:
            print("Nome utente non trovato.")
            return None
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return None

if __name__ == "__main__":
    url = "https://www.miodottore.it/gianluca-merola/medico-estetico-dietologo-nutrizionista/roma#address-id=%5B277842%2C746095%2C761065%5D&filters%5Bspecializations%5D%5B%5D=108"
    username = get_username(url)

    if username:
        print("Nome utente:", username)
    else:
        print("Impossibile ottenere il nome utente dalla pagina.")
# Out:
# Nome utente: Gianluca Merola

# %% [markdown]
# [
#   {
#     "Codice Regione": 1,
#     "Codice Città Metropolitana": 201,
#     "Codice Provincia (1)": 1,
#     "Progressivo del Comune (2)": 1,
#     "Codice Comune formato alfanumerico": 1001,
#     "Denominazione in italiano": "Agliè",
#     "Denominazione in tedesco": "",
#     "Codice Ripartizione Geografica": 1,
#     "Ripartizione geografica": "Nord-ovest",
#     "Denominazione regione": "Piemonte",
#     "Denominazione Città metropolitana": "Torino",
#     "Denominazione provincia": "-",
#     "Flag Comune capoluogo di provincia": 0,
#     "Sigla automobilistica": "TO",
#     "Codice Comune formato numerico": 1001,
#     "Codice Comune numerico con 107 province (dal 2006 al 2009)": 1001,
#     "Codice Comune numerico con 103 province (dal 1995 al 2005)": 1001,
#     "Codice Catastale del comune": "A074",
#     "Popolazione legale 2011 (09/10/2011)": 2.644,
#     "Codice NUTS1 2010": "ITC",
#     "Codice NUTS2 2010 (3)": "ITC1",
#     "Codice NUTS3 2010": "ITC11",
#     "Codice NUTS1 2006": "ITC",
#     "Codice NUTS2 2006 (3)": "ITC1",
#     "Codice NUTS3 2006": "ITC11"
#   },
#   {

# %% [markdown]
# Roma Nutrizionista

# %% [markdown]
# https://www.miodottore.it/cerca?q=nutrizionista&loc=Roma&filters%5Bspecializations%5D%5B%5D=108

# %% [markdown]
# https://www.miodottore.it/cerca?q=Nutrizionista&loc=Bracciano%2C%20FC&filters[specializations][]=108

# %% [markdown]
# https://www.miodottore.it/cerca?q=Nutrizionista&loc=Bracciano%2C%20RM&filters[specializations][]=108

# %%
import csv
import requests
from bs4 import BeautifulSoup
from collections import Counter
import re

def scarica_nomi_citta():
    url = "https://en.wikipedia.org/wiki/List_of_cities_in_Italy"
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        nomi_citta = []

        # Troviamo tutte le righe della tabella con il tag 'td' e attributo 'align="left"'
        for td in soup.find_all('td', align='left'):
            # Troviamo il tag 'a' all'interno del tag 'td'
            a_tag = td.find('a')
            if a_tag and a_tag.has_attr('title'):
                nome_citta = a_tag['title']
                nomi_citta.append(nome_citta)

        return nomi_citta
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []



def elemento_piu_ripetuto(lista):
    # Utilizziamo Counter per contare le occorrenze degli elementi nella lista
    conteggio = Counter(lista)

    # Troviamo l'elemento con la conteggio massimo
    elemento_piu_comune = conteggio.most_common(1)[0][0]

    return elemento_piu_comune

def get_links(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        links = [a['href'] for a in soup.find_all('a', href=True)]
        return links
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []

def get_username(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        
        username_element = soup.find('span', itemprop='name')

        if username_element:
            username = username_element.text.strip()
            return username
        else:
            print("Nome utente non trovato.")
            return None
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return None

def find_phone_number(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        phone_pattern = r"\b\d{2,4}\s?\d{6,10}\b"  # Regular expression pattern to match phone numbers
        matches = re.findall(phone_pattern, response.text)
        return matches
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []

def rimuovi_duplicati_csv(input_file, output_file):
    unique_data = set()

    # Leggi il file CSV in input e rimuovi i duplicati
    with open(input_file, 'r', newline='') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            unique_data.add(tuple(row))  # Converti la riga in una tupla per rendere gli elementi immutabili

    # Scrivi i dati unici nel file CSV di output
    with open(output_file, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        for row in unique_data:
            writer.writerow(row)

def lista_senza_ripetizioni(lista):
    lista_senza_duplicati = list(set(lista))
    return lista_senza_duplicati

def aggiungi_datapoint_a_csv(file_path, datapoint):
    try:
        with open(file_path, 'a', newline='') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(datapoint)
        print("Datapoint aggiunto con successo al file CSV.")
    except Exception as e:
        print("Errore durante l'aggiunta del datapoint:", e)

if __name__ == "__main__":
    input_file = "input_data.csv"
    output_file = "final_data.csv"
    lista_citta = scarica_nomi_citta()
    lavori = ['Nutrizionista'] #,'chirurgo estetico','chirurgo plastico']
    MAX_POSSIBLE_PAGE = 82
    for lavoro in lavori:
        for citta in lista_citta:
            counter_error = 0
            for page_number in range(1,MAX_POSSIBLE_PAGE):
                if counter_error < 4:
                
                    try:
                        try:
                            LINK = f"https://www.miodottore.it/cerca?q={lavoro}&loc={citta}&filters[specializations][0]=108&page={page_number}"
                            LINKS = get_links(LINK)
                            print(LINKS)
                            for link in LINKS:
                                if "https://www.miodottore.it/" in link and not "https://www.miodottore.it/strutture" in link:
                                    
                                    print(link)
                                    phone_numbers = find_phone_number(link)
                                    username = get_username(url=link)
                                    id = elemento_piu_ripetuto(phone_numbers)
                                    elementi_stringa = ','.join(map(str, lista_senza_duplicati(phone_numbers)))
                                    datapoint = id, username, citta, lavoro, elementi_stringa
                                    print(datapoint)
                                    aggiungi_datapoint_a_csv(input_file, datapoint)
                        except:
                            print("page error")

                    except:
                        print("counter error")
                        counter_error+=1

    rimuovi_duplicati_csv(input_file, output_file)
    print("CSV creato")
# Out:
# ['/', '#', '#', '#', '#', '#', '#', 'https://www.miodottore.it/registrazione-medico', 'https://pro.miodottore.it/?utm_source=MKTP&utm_medium=referral&utm_campaign=top-nav', '#recommended-sorting-disclaimer-modal', 'https://www.miodottore.it/vincenzo-marzolla/nutrizionista/roma', 'https://www.miodottore.it/vincenzo-marzolla/nutrizionista/roma', 'https://www.miodottore.it/vincenzo-marzolla/nutrizionista/roma#profile-reviews', 'https://www.google.com/maps/search/?api=1&query=41.852932,12.5672398', 'https://www.miodottore.it/elena-colabianchi/nutrizionista-chinesiologo-professional-counselor/roma', 'https://www.miodottore.it/elena-colabianchi/nutrizionista-chinesiologo-professional-counselor/roma', 'https://www.miodottore.it/elena-colabianchi/nutrizionista-chinesiologo-professional-counselor/roma#profile-reviews', 'https://www.google.com/maps/search/?api=1&query=41.863739,12.4573298', 'https://www.google.com/maps/search/?api=1&query=41.863205,12.4604073', 'https://www.miodottore.it/strut
# ...
